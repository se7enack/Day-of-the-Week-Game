# %% [markdown]
# <a href="https://colab.research.google.com/github/se7enack/Day-of-the-Week-Champ/blob/main/dategame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf *
# !wget https://raw.githubusercontent.com/se7enack/Day-of-the-Week-Champ/refs/heads/main/buildozer.spec
# !wget https://raw.githubusercontent.com/se7enack/Day-of-the-Week-Champ/refs/heads/main/main.py
# !wget https://raw.githubusercontent.com/se7enack/Day-of-the-Week-Champ/refs/heads/main/perfect.mp3
# !wget https://raw.githubusercontent.com/se7enack/Day-of-the-Week-Champ/refs/heads/main/good.mp3
# !wget https://raw.githubusercontent.com/se7enack/Day-of-the-Week-Champ/refs/heads/main/bad.mp3
# !wget https://raw.githubusercontent.com/se7enack/Day-of-the-Week-Champ/refs/heads/main/fail.mp3
# Out:
# --2025-11-11 18:02:32--  https://raw.githubusercontent.com/se7enack/Day-of-the-Week-Champ/refs/heads/main/buildozer.spec
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16532 (16K) [text/plain]
# Saving to: ‘buildozer.spec’
#
# buildozer.spec      100%[===================>]  16.14K  --.-KB/s    in 0.001s
#
# 2025-11-11 18:02:32 (23.7 MB/s) - ‘buildozer.spec’ saved [16532/16532]
#
# --2025-11-11 18:02:32--  https://raw.githubusercontent.com/se7enack/Day-of-the-Week-Champ/refs/heads/main/main.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# ...

# %%
# !pip3 install --upgrade Cython==0.29.33 virtualenv buildozer

# %%
# !pip install kivymd kivy pillow python-for-android

# %%
# !sudo apt-get install -y \
    autoconf \
    build-essential \
    bzip2 \
    cmake \
    ffmpeg \
    git \
    git zip \
    libavcodec-dev \
    libavformat-dev \
    libbz2-dev \
    libffi-dev \
    libffi7 \
    libgdbm-compat-dev \
    libgdbm-dev \
    liblzma-dev \
    libncurses5-dev \
    libncursesw5-dev \
    libportmidi-dev \
    libreadline-dev \
    libsdl2-dev \
    libsdl2-image-dev \
    libsdl2-mixer-dev \
    libsdl2-ttf-dev \
    libsqlite3-dev \
    libssl-dev \
    libswscale-dev \
    libtinfo5 \
    libtool \
    openjdk-17-jdk \
    openssl \
    pkg-config \
    python3 \
    python3-dev \
    python3-pip \
    sqlite3 \
    unzip \
    uuid-dev \
    zlib1g-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# autoconf is already the newest version (2.71-2).
# build-essential is already the newest version (12.9ubuntu3).
# bzip2 is already the newest version (1.0.8-5build1).
# libbz2-dev is already the newest version (1.0.8-5build1).
# libffi-dev is already the newest version (3.4.2-4).
# libgdbm-compat-dev is already the newest version (1.23-1).
# libgdbm-dev is already the newest version (1.23-1).
# liblzma-dev is already the newest version (5.2.5-2ubuntu1).
# libreadline-dev is already the newest version (8.1.2-1).
# libtool is already the newest version (2.4.6-15build2).
# pkg-config is already the newest version (0.29.2-1ubuntu3).
# zip is already the newest version (3.0-12build2).
# libffi7 is already the newest version (3.3-5ubuntu1).
# libportmidi-dev is already the newest version (1:217-6).
# libsdl2-image-dev is already the newest version (2.0.5+dfsg1-3build1).
# ...

# %%
# !sudo apt autoremove
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.

# %%
!#yes | buildozer android clean

# %%
!#yes | buildozer init

# %%
# !yes | buildozer -v android debug
# Out:
# # Check configuration tokens
# Buildozer is running as root!
# This is not recommended, and may lead to problems later.
# Are you sure you want to continue [y/n]? # Ensure build layout
# # Create directory /content/bin
# # Check configuration tokens
# # Preparing build
# # Check requirements for android
# # Search for Git (git)
# #  -> found at /usr/bin/git
# # Search for Cython (cython)
# #  -> found at /usr/local/bin/cython
# # Search for Java compiler (javac)
# #  -> found at /usr/lib/jvm/java-17-openjdk-amd64/bin/javac
# # Search for Java keytool (keytool)
# #  -> found at /usr/lib/jvm/java-17-openjdk-amd64/bin/keytool
# # Install platform
# # Run ['git', 'config', '--get', 'remote.origin.url']
# # Cwd /content/.buildozer/android/platform/python-for-android
# https://github.com/kivy/python-for-android.git
# # Run ['git', 'branch', '-vv']
# # Cwd /content/.buildozer/android/platform/python-for-android
# ...
